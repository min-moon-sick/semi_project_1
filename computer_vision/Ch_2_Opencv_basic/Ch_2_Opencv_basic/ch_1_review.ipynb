# %%
import cv2
import numpy as np
import sys

# %%
img = cv2.imread('/Users/HPE/Documents/computer_vision/Ch_1_Opencv_Intro/Ch_1_Opencv_Intro/fig/puppy.bmp', cv2.IMREAD_COLOR)
print(img.shape)

h, w = img.shape[:2]

# img_re = cv2.resize(img, (w//2, h//2), interpolation = cv2.INTER_AREA)
img_re = cv2.resize(img, (0, 0), fx = 0.5, fy = 1, interpolation = cv2.INTER_AREA) # fx, fy로 사이즈 조절

if img is None:
    print('image read failed')
    sys.exit()
    
cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.imshow('image', img)
cv2.imshow('image_re', img_re)

while 1:
    key = cv2.waitKey()
    
    if key == 27 or key == ord('q'):
        break
#     elif key == ord('s'):
#         cv2.
        
cv2.destroyAllWindows()
# Out:
# (480, 640, 3)

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
import sys

imgBGR = cv2.imread('/Users/HPE/Documents/computer_vision/Ch_1_Opencv_Intro/Ch_1_Opencv_Intro/fig/cat.bmp', cv2.IMREAD_COLOR)
imgGRAY = cv2.imread('/Users/HPE/Documents/computer_vision/Ch_1_Opencv_Intro/Ch_1_Opencv_Intro/fig/cat.bmp', 0)

if imgBGR is None:
    print('image read failed')
    sys.exit()
    
imgRGB = cv2.cvtColor(imgBGR, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10,5))
plt.subplot(1, 3, 1), plt.imshow(imgBGR), plt.axis('off')
plt.subplot(1, 3, 2), plt.imshow(imgRGB), plt.axis('off')
plt.subplot(1, 3, 3), plt.imshow(imgGRAY, cmap = "gray"), plt.axis('off')
# Out:
# (<AxesSubplot:>,
# ...
#  (-0.5, 639.5, 479.5, -0.5))

# %% [markdown]
# ## 이미지 슬라이드(영상을 전체 화면으로 띄우기)

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
import os
import sys

path = '/Users/HPE/Documents/computer_vision/Ch_1_Opencv_Intro/Ch_1_Opencv_Intro/fig/images/'
img_list = os.listdir(path)

img_files = []

for i in img_list:
    img_file = path + i
    img_files.append(img_file)
    
cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.setWindowProperty('image', cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

idx = 0
while 1:
    img = cv2.imread(img_files[idx])
    cv2.imshow('image', img)
    
    if cv2.waitKey(3000) == 27:
        break
        
    idx += 1
    
    if idx == len(img_files):
        idx = 0
cv2.destroyAllWindows()

# %% [markdown]
# ### 이미지 슬라이드 실습

# %%
import cv2
import os
import sys
import numpy as np

path = '/Users/HPE/Documents/landscape/'
img_file_list = os.listdir(path)

path_img_list = []

for i in img_file_list:
    path_img_list.append(path + i)
    
path_img_list
cv2.namedWindow('image', cv2.WINDOW_GUI_NORMAL)
cv2.setWindowProperty('image',cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

idx = 0
while 1:
    img = cv2.imread(path_img_list[idx])
    cv2.imshow('image', img)
    
    if cv2.waitKey(3000) == 27:
        break
    
    idx += 1
    
    if idx == len(path_img_list):
        idx = 0
        
cv2.destroyAllWindows()
